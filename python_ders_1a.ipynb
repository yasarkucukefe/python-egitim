# %%
print("Merhaba Dünya")
# Out:
# Merhaba Dünya

# %%
2+1
# Out:
# 3

# %%
7 % 3
# Out:
# 1

# %%
# Üstlü sayılar
2**3
# Out:
# 8

# %%
(2+3)+5*5+12
# Out:
# 42

# %% [markdown]
# ## Değişkenler

# %%
a = 10

# %%
a
# Out:
# 10

# %%
b = a + 20

# %%
b
# Out:
# 30

# %%
a + b + 20
# Out:
# 60

# %%
fiyat = 100
kdv = fiyat * 0.18
toplam = fiyat + kdv
print("Toplam fiyat ", toplam)
# Out:
# Toplam fiyat  118.0

# %%
isim = "Yaşar Küçükefe"

# %%
len(isim)
# Out:
# 14

# %%
isim[0]
# Out:
# 'Y'

# %%
isim[3]
# Out:
# 'a'

# %%
isim[3:]
# Out:
# 'ar Küçükefe'

# %%
isim[-2:]
# Out:
# 'fe'

# %%
isim[-3:]
# Out:
# 'efe'

# %%
isim[:-3]
# Out:
# 'Yaşar Küçük'

# %%
merhaba = "merhaba "+isim

# %%
merhaba
# Out:
# 'merhaba Yaşar Küçükefe'

# %%
harf = 'k'

# %%
harf * 10
# Out:
# 'kkkkkkkkkk'

# %%
'Merhaba {}'.format(isim)
# Out:
# 'Merhaba Yaşar Küçükefe'

# %%
isim_='Ali'
soyisim_=' Cumali'
'Benim adım {}, soyadım {}'.format(isim_,soyisim_)
# Out:
# 'Benim adım Ali, soyadım  Cumali'

# %%
"Benim adım "+isim_+", soyadım "+soyisim_
# Out:
# 'Benim adım Ali, soyadım  Cumali'

# %%
'Arkadaşlarımın isimleri {2}, {0}, ve {1}'.format('Mehmet','Cem','Ayşe')
# Out:
# 'Arkadaşlarımın isimleri Ayşe, Mehmet, ve Cem'

# %%
'Araba modelleri {a}, {b}, {c}'.format(c='Toyota Prius',a='Honda Civic',b='Mercedes C180')
# Out:
# 'Araba modelleri Honda Civic, Mercedes C180, Toyota Prius'

# %%
isim = "Ceyda"
print('Bugün sınıfta görmedim {}'.format(isim))
# Out:
# Bugün sınıfta görmedim Ceyda

# %%
liste = [1, 2, 3, 4]

# %%
print(liste)
# Out:
# [1, 2, 3, 4]

# %%
type(liste)
# Out:
# list

# %%
type(isim)
# Out:
# str

# %%
liste2 = ['Ali',45,'Mehmet',100,'Ayşe',21]

# %%
print(liste2)
# Out:
# ['Ali', 45, 'Mehmet', 100, 'Ayşe', 21]

# %%
liste2[0]
# Out:
# 'Ali'

# %%
liste2[3:]
# Out:
# [100, 'Ayşe', 21]

# %%
liste2 = liste2 + ['Cem',71]

# %%
liste2
# Out:
# ['Ali', 45, 'Mehmet', 100, 'Ayşe', 21, 'Cem', 71]

# %%
liste3 = 2 * liste

# %%
liste3
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
liste2 * 3
# Out:
# ['Ali',
#  45,
#  'Mehmet',
#  100,
#  'Ayşe',
#  21,
#  'Cem',
#  71,
#  'Ali',
#  45,
#  'Mehmet',
#  100,
#  'Ayşe',
#  21,
#  'Cem',
#  71,
#  'Ali',
#  45,
#  'Mehmet',
#  100,
#  'Ayşe',
#  21,
#  'Cem',
#  71]

# %%
liste.append(5)

# %%
liste
# Out:
# [1, 2, 3, 4, 5]

# %%
liste2.append('Müjde')

# %%
liste
# Out:
# [1, 2, 3, 4, 5]

# %%
liste.pop(0)
# Out:
# 1

# %%
liste
# Out:
# [2, 3, 4, 5]

# %%
liste[0]
# Out:
# 2

# %%
liste[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-63-03d2c8a7fb67> in <module>()
# ----> 1 liste[10]
#
# IndexError: list index out of range

# %%
lst_1=[1,2,3]
lst_2=[4,5,6]
lst_3=[7,8,9]

# %%
matris = [lst_1, lst_2, lst_3]

# %%
matris
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matris[0]
# Out:
# [1, 2, 3]

# %%
matris[0][1]
# Out:
# 2

# %%
liste2
# Out:
# ['Ali', 45, 'Mehmet', 100, 'Ayşe', 21, 'Cem', 71, 'Müjde']

# %%
for deger in liste2:
    print("Deger: ",deger)
# Out:
# Deger:  Ali
# Deger:  45
# Deger:  Mehmet
# Deger:  100
# Deger:  Ayşe
# Deger:  21
# Deger:  Cem
# Deger:  71
# Deger:  Müjde

# %% [markdown]
# ## Dictionary

# %%
sozluk = {'a1':'deger_1','a2':'deger_2'}

# %%
sozluk['a1']
# Out:
# 'deger_1'

# %%
turkce = {'a1':'Günaydın','a2':'iyi_aksamlar'}
ingilizce = {'a1':'Good morning','a2':'Good night'}

# %%
sozluk = turkce
print (sozluk['a1'])
# Out:
# Günaydın

# %%
sozluk = ingilizce
print (sozluk['a1'])
# Out:
# Good morning

# %%
sozluk.keys()
# Out:
# dict_keys(['a2', 'a1'])

# %%
sozluk.values()
# Out:
# dict_values(['Good night', 'Good morning'])

# %% [markdown]
# ## Tuples

# %%
demet = (1,2,3,4)

# %%
liste
# Out:
# [2, 3, 4, 5]

# %%
demet
# Out:
# (1, 2, 3, 4)

# %%
print('demet =>'+str(type(demet)))
# Out:
# demet =><class 'tuple'>

# %%
print('liste =>'+str(type(liste)))
# Out:
# liste =><class 'list'>

# %%
demet.index(3)
# Out:
# 2

# %%
#Immutability
liste[0]=10

# %%
liste[0]
# Out:
# 10

# %%
demet[0]=20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-531720a39061> in <module>()
# ----> 1 demet[0]=20
#
# TypeError: 'tuple' object does not support item assignment

# %%
demet.append(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-213c2716de56> in <module>()
# ----> 1 demet.append(0)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
demet.pop(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-557a84c3322e> in <module>()
# ----> 1 demet.pop(0)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %% [markdown]
# ## Set (Küme)

# %%
x = set()

# %%
x.add(1)

# %%
x.add(2)

# %%
x.add(3)

# %%
print(x)
# Out:
# {1, 2, 3}

# %%
x.add(1)

# %%
print(x)
# Out:
# {1, 2, 3}

# %%
list1 = [1,23,1,2,3,42,20,2,11,3,2,4,2,358,53,1,23,1,25,652,24,24,1,2,4,5]

# %%
kume1 = set(list1)

# %%
print(kume1)
# Out:
# {1, 2, 3, 4, 5, 358, 42, 11, 652, 20, 53, 23, 24, 25}

# %% [markdown]
# ## Boolean

# %%
a = True
b = False

# %%
1 > 0
# Out:
# True

# %%
c = None

# %%
print(c)
# Out:
# None

# %% [markdown]
# ## Dosyalar

# %%
my_file = open("dosya.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-109-79f32a65431f> in <module>()
# ----> 1 my_file = open("dosya.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dosya.txt'

# %%
# %%writefile -a dosya.txt
# Out:
# UsageError: %%writefile is a cell magic, but the cell body is empty.

# %%
# %%writefile -a dosya.txt
# Bu yeni oluşturulan bir dosyadır.
# Out:
# Writing dosya.txt

# %%
my_file = open("dosya.txt")

# %%
my_file
# Out:
# <_io.TextIOWrapper name='dosya.txt' mode='r' encoding='cp1252'>

# %%
for metin in my_file:
    print(metin)
# Out:
# Bu yeni oluÅŸturulan bir dosyadÄ±r.

# %% [markdown]
# ## Alıştırma

# %%
# 100'ün kara kökü?
100**(1/2)
# Out:
# 10.0

# %%
liste
# Out:
# [10, 3, 4, 5]

# %%
liste.sort()

# %%
print(liste)
# Out:
# [3, 4, 5, 10]
